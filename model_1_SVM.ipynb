# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\amhlo\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\amhlo\anaconda3\lib\site-packages (from sklearn) (0.22.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\amhlo\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.14.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\users\amhlo\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.18.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in c:\users\amhlo\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.4.1)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\amhlo\anaconda3\lib\site-packages (0.14.1)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head(100)
# Out:
#    koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0        CONFIRMED              0              0              0
# 1   FALSE POSITIVE              0              1              0
# 2   FALSE POSITIVE              0              1              0
# 3        CONFIRMED              0              0              0
# 4        CONFIRMED              0              0              0
# ..             ...            ...            ...            ...
# 95       CONFIRMED              0              0              0
# 96       CONFIRMED              0              0              0
# 97       CONFIRMED              0              0              0
# 98       CONFIRMED              0              0              0
# 99       CONFIRMED              0              0              0
#
#     koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0               0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1               0   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2               0    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3               0    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4               0    4.134435     1.050000e-05    -1.050000e-05   172.979370
# ..            ...         ...              ...              ...          ...
# 95              0    8.103633     2.030000e-05    -2.030000e-05   176.948600
# 96              0    4.715108     1.940000e-05    -1.940000e-05   134.961780
# 97              0    6.365840     8.060000e-06    -8.060000e-06   171.135750
# 98              0    3.040330     3.370000e-07    -3.370000e-07   169.949011
# 99              0   31.330461     3.980000e-05    -3.980000e-05   153.430310
#
#     koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0           0.003520  ...             -81      4.467           0.064
# 1           0.000581  ...            -176      4.544           0.044
# 2           0.000115  ...            -174      4.564           0.053
# 3           0.001130  ...            -211      4.438           0.070
# 4           0.001900  ...            -232      4.486           0.054
# ..               ...  ...             ...        ...             ...
# 95          0.002050  ...            -146      4.574           0.054
# 96          0.003240  ...            -146      4.574           0.054
# 97          0.001000  ...            -155      4.554           0.042
# 98          0.000089  ...            -151      4.519           0.084
# 99          0.001030  ...            -105      4.581           0.010
#
#     koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0           -0.096     0.927          0.105         -0.061  291.93423
# 1           -0.176     0.868          0.233         -0.078  297.00482
# 2           -0.168     0.791          0.201         -0.067  285.53461
# 3           -0.210     1.046          0.334         -0.133  288.75488
# 4           -0.229     0.972          0.315         -0.105  296.28613
# ..             ...       ...            ...            ...        ...
# 95          -0.041     0.732          0.062         -0.068  283.22141
# 96          -0.041     0.732          0.062         -0.068  283.22141
# 97          -0.168     0.849          0.212         -0.071  291.14951
# 98          -0.063     0.791          0.071         -0.087  299.31610
# 99          -0.085     0.817          0.080         -0.029  292.23676
#
#           dec  koi_kepmag
# 0   48.141651      15.347
# 1   48.134129      15.436
# 2   48.285210      15.597
# 3   48.226200      15.509
# 4   48.224670      15.714
# ..        ...         ...
# 95  40.421829      15.289
# 96  40.421829      15.289
# 97  40.420521      15.090
# 98  40.822380      15.028
# 99  41.085880      15.855
#
# [100 rows x 41 columns]

# %%
print(df.columns)
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
# Features are selected from the top 10 from the Random Forest model
selected_features = df[['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec', 'koi_prad', 'koi_model_snr', 
                       'koi_prad_err2', 'koi_duration_err2', 'koi_prad_err1', 'koi_duration_err1']]
selected_features.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_prad  \
# 0              0              0              0              0      2.83
# 1              0              1              0              0     14.60
# 2              0              1              0              0     33.46
# 3              0              0              0              0      2.75
# 4              0              0              0              0      2.77
#
#    koi_model_snr  koi_prad_err2  koi_duration_err2  koi_prad_err1  \
# 0           25.8          -0.19           -0.11600           0.32
# 1           76.3          -1.31           -0.03410           3.92
# 2          505.6          -2.83           -0.00537           8.50
# 3           40.9          -0.35           -0.04200           0.88
# 4           40.2          -0.30           -0.06730           0.90
#
#    koi_duration_err1
# 0            0.11600
# 1            0.03410
# 2            0.00537
# 3            0.04200
# 4            0.06730

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# set X and y variables
X = selected_features
y = df['koi_disposition']

# %%
# split data to train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_prad  \
# 6122              0              0              0              0      1.24
# 6370              0              1              0              1      0.86
# 2879              1              0              0              0      3.21
# 107               0              0              0              0      2.25
# 29                0              0              0              0     12.21
#
#       koi_model_snr  koi_prad_err2  koi_duration_err2  koi_prad_err1  \
# 6122           10.8          -0.23            -0.3060           0.34
# 6370           13.8          -0.06            -0.2820           0.23
# 2879          254.3          -0.32             0.0000           0.97
# 107            38.4          -0.14            -0.0595           0.07
# 29            696.5          -1.46            -0.0075           1.96
#
#       koi_duration_err1
# 6122             0.3060
# 6370             0.2820
# 2879             0.0000
# 107              0.0595
# 29               0.0075

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)

X_train_scaled = X_minmax.transform(X_train)
X_test_scaled = X_minmax.transform(X_test)

# %% [markdown]
# # Train the Model (SVM)

# %%
from sklearn.svm import SVC
model = SVC(kernel = 'linear')
model.fit(X_train_scaled, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.7715048636276941
# Testing Data Score: 0.7820366132723112

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10, 50],
             'gamma': [0.0001, 0.0005, 0.001, 0.005]}
grid = GridSearchCV(model, param_grid, verbose = 3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.774, total=   0.1s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] ................... C=1, gamma=0.0001, score=0.760, total=   0.1s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.765, total=   0.1s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.760, total=   0.1s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] ................... C=1, gamma=0.0001, score=0.768, total=   0.1s
# [CV] C=1, gamma=0.0005 ...............................................
# [CV] ................... C=1, gamma=0.0005, score=0.774, total=   0.1s
# [CV] C=1, gamma=0.0005 ...............................................
# [CV] ................... C=1, gamma=0.0005, score=0.760, total=   0.1s
# [CV] C=1, gamma=0.0005 ...............................................
# [CV] ................... C=1, gamma=0.0005, score=0.765, total=   0.1s
# [CV] C=1, gamma=0.0005 ...............................................
# [CV] ................... C=1, gamma=0.0005, score=0.760, total=   0.1s
# [CV] C=1, gamma=0.0005 ...............................................
# [CV] ................... C=1, gamma=0.0005, score=0.768, total=   0.1s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.774, total=   0.1s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.760, total=   0.1s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.765, total=   0.1s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.760, total=   0.1s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.768, total=   0.1s
# [CV] C=1, gamma=0.005 ................................................
# [CV] .................... C=1, gamma=0.005, score=0.774, total=   0.1s
# [CV] C=1, gamma=0.005 ................................................
# [CV] .................... C=1, gamma=0.005, score=0.760, total=   0.1s
# [CV] C=1, gamma=0.005 ................................................
# [CV] .................... C=1, gamma=0.005, score=0.765, total=   0.1s
# [CV] C=1, gamma=0.005 ................................................
# [CV] .................... C=1, gamma=0.005, score=0.760, total=   0.1s
# [CV] C=1, gamma=0.005 ................................................
# [CV] .................... C=1, gamma=0.005, score=0.768, total=   0.1s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.825, total=   0.1s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.810, total=   0.1s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.817, total=   0.1s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.804, total=   0.1s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.821, total=   0.1s
# [CV] C=5, gamma=0.0005 ...............................................
# [CV] ................... C=5, gamma=0.0005, score=0.825, total=   0.1s
# [CV] C=5, gamma=0.0005 ...............................................
# [CV] ................... C=5, gamma=0.0005, score=0.810, total=   0.1s
# [CV] C=5, gamma=0.0005 ...............................................
# [CV] ................... C=5, gamma=0.0005, score=0.817, total=   0.1s
# [CV] C=5, gamma=0.0005 ...............................................
# [CV] ................... C=5, gamma=0.0005, score=0.804, total=   0.1s
# [CV] C=5, gamma=0.0005 ...............................................
# [CV] ................... C=5, gamma=0.0005, score=0.821, total=   0.1s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.825, total=   0.1s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.810, total=   0.1s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.817, total=   0.1s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.804, total=   0.1s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.821, total=   0.1s
# [CV] C=5, gamma=0.005 ................................................
# [CV] .................... C=5, gamma=0.005, score=0.825, total=   0.1s
# [CV] C=5, gamma=0.005 ................................................
# [CV] .................... C=5, gamma=0.005, score=0.810, total=   0.1s
# [CV] C=5, gamma=0.005 ................................................
# [CV] .................... C=5, gamma=0.005, score=0.817, total=   0.1s
# [CV] C=5, gamma=0.005 ................................................
# [CV] .................... C=5, gamma=0.005, score=0.804, total=   0.1s
# [CV] C=5, gamma=0.005 ................................................
# [CV] .................... C=5, gamma=0.005, score=0.821, total=   0.1s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.846, total=   0.1s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.835, total=   0.1s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.829, total=   0.1s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.823, total=   0.1s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.830, total=   0.1s
# [CV] C=10, gamma=0.0005 ..............................................
# [CV] .................. C=10, gamma=0.0005, score=0.846, total=   0.1s
# [CV] C=10, gamma=0.0005 ..............................................
# [CV] .................. C=10, gamma=0.0005, score=0.835, total=   0.1s
# [CV] C=10, gamma=0.0005 ..............................................
# [CV] .................. C=10, gamma=0.0005, score=0.829, total=   0.1s
# [CV] C=10, gamma=0.0005 ..............................................
# [CV] .................. C=10, gamma=0.0005, score=0.823, total=   0.1s
# [CV] C=10, gamma=0.0005 ..............................................
# [CV] .................. C=10, gamma=0.0005, score=0.830, total=   0.1s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.846, total=   0.1s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.835, total=   0.1s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.829, total=   0.1s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.823, total=   0.1s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.830, total=   0.1s
# [CV] C=10, gamma=0.005 ...............................................
# [CV] ................... C=10, gamma=0.005, score=0.846, total=   0.1s
# [CV] C=10, gamma=0.005 ...............................................
# [CV] ................... C=10, gamma=0.005, score=0.835, total=   0.1s
# [CV] C=10, gamma=0.005 ...............................................
# [CV] ................... C=10, gamma=0.005, score=0.829, total=   0.1s
# [CV] C=10, gamma=0.005 ...............................................
# [CV] ................... C=10, gamma=0.005, score=0.823, total=   0.1s
# [CV] C=10, gamma=0.005 ...............................................
# [CV] ................... C=10, gamma=0.005, score=0.830, total=   0.1s
# [CV] C=50, gamma=0.0001 ..............................................
# [CV] .................. C=50, gamma=0.0001, score=0.865, total=   0.1s
# [CV] C=50, gamma=0.0001 ..............................................
# [CV] .................. C=50, gamma=0.0001, score=0.857, total=   0.1s
# [CV] C=50, gamma=0.0001 ..............................................
# [CV] .................. C=50, gamma=0.0001, score=0.851, total=   0.1s
# [CV] C=50, gamma=0.0001 ..............................................
# [CV] .................. C=50, gamma=0.0001, score=0.841, total=   0.1s
# [CV] C=50, gamma=0.0001 ..............................................
# [CV] .................. C=50, gamma=0.0001, score=0.844, total=   0.1s
# [CV] C=50, gamma=0.0005 ..............................................
# [CV] .................. C=50, gamma=0.0005, score=0.865, total=   0.1s
# [CV] C=50, gamma=0.0005 ..............................................
# [CV] .................. C=50, gamma=0.0005, score=0.857, total=   0.1s
# [CV] C=50, gamma=0.0005 ..............................................
# [CV] .................. C=50, gamma=0.0005, score=0.851, total=   0.1s
# [CV] C=50, gamma=0.0005 ..............................................
# [CV] .................. C=50, gamma=0.0005, score=0.841, total=   0.1s
# [CV] C=50, gamma=0.0005 ..............................................
# [CV] .................. C=50, gamma=0.0005, score=0.844, total=   0.1s
# [CV] C=50, gamma=0.001 ...............................................
# [CV] ................... C=50, gamma=0.001, score=0.865, total=   0.1s
# [CV] C=50, gamma=0.001 ...............................................
# [CV] ................... C=50, gamma=0.001, score=0.857, total=   0.1s
# [CV] C=50, gamma=0.001 ...............................................
# [CV] ................... C=50, gamma=0.001, score=0.851, total=   0.1s
# [CV] C=50, gamma=0.001 ...............................................
# [CV] ................... C=50, gamma=0.001, score=0.841, total=   0.1s
# [CV] C=50, gamma=0.001 ...............................................
# [CV] ................... C=50, gamma=0.001, score=0.844, total=   0.1s
# [CV] C=50, gamma=0.005 ...............................................
# [CV] ................... C=50, gamma=0.005, score=0.865, total=   0.1s
# [CV] C=50, gamma=0.005 ...............................................
# [CV] ................... C=50, gamma=0.005, score=0.857, total=   0.1s
# [CV] C=50, gamma=0.005 ...............................................
# [CV] ................... C=50, gamma=0.005, score=0.851, total=   0.1s
# [CV] C=50, gamma=0.005 ...............................................
# [CV] ................... C=50, gamma=0.005, score=0.841, total=   0.1s
# [CV] C=50, gamma=0.005 ...............................................
# [CV] ................... C=50, gamma=0.005, score=0.844, total=   0.1s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:    7.4s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='linear', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [1, 5, 10, 50],
#                          'gamma': [0.0001, 0.0005, 0.001, 0.005]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 50, 'gamma': 0.0001}
# 0.851417380420466

# %%
# calculate the classification report
from sklearn.metrics import classification_report
predictions = grid.predict(X_test_scaled)
print(classification_report(y_test, predictions))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.81      0.50      0.62       411
#      CONFIRMED       0.68      0.88      0.77       484
# FALSE POSITIVE       0.98      1.00      0.99       853
#
#       accuracy                           0.85      1748
#      macro avg       0.82      0.79      0.79      1748
#   weighted avg       0.86      0.85      0.84      1748

# %%
# Printing the confusion matrix
# The columns will show the instances predicted for each label,
# and the rows will show the actual number of instances for each label
from sklearn.metrics import confusion_matrix
predictions = grid.predict(X_test_scaled)
print(confusion_matrix(y_test, predictions))
# Out:
# [[206 199   6]
#  [ 46 427  11]
#  [  2   0 851]]

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'Austin_modelSVM.sav'
joblib.dump(model, filename)
# Out:
# ['Austin_modelSVM.sav']
