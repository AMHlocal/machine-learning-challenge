# %%
import pandas as pd
from os import path
from sklearn import tree

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
target = df['koi_disposition']

# %%
data = df.drop('koi_disposition', axis=1)
features = data.columns
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %%
# split data to train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
# Scale your data
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)

X_train_scaled = X_minmax.transform(X_train)
X_test_scaled = X_minmax.transform(X_test)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
#find the important features
importances = clf.feature_importances_
importances
# Out:
# array([0.1949848 , 0.17331824, 0.18322372, 0.02983544, 0.00972653,
#        0.0039581 , 0.00277092, 0.01348242, 0.00829093, 0.0085748 ,
#        0.02809629, 0.00598293, 0.00577116, 0.01091805, 0.00549427,
#        0.00617998, 0.00630955, 0.00807468, 0.00835359, 0.01379905,
#        0.00856979, 0.00475707, 0.0037258 , 0.00315693, 0.00814702,
#        0.00282354, 0.13578664, 0.00467109, 0.01003026, 0.01247274,
#        0.01068247, 0.00342747, 0.00312616, 0.00893143, 0.00151714,
#        0.01216485, 0.00556689, 0.00885846, 0.0155187 , 0.00892009])

# %%
#sort important features to get the top 10 using sorted(zip), learned from lecture
sorted(zip(importances, features), reverse=True)
# Out:
# [(0.19498480426684972, 'koi_fpflag_nt'),
#  (0.18322372199330475, 'koi_fpflag_co'),
#  (0.1733182396202466, 'koi_fpflag_ss'),
#  (0.13578663728115684, 'koi_model_snr'),
#  (0.029835439379031353, 'koi_fpflag_ec'),
#  (0.028096293201116933, 'koi_impact'),
#  (0.015518699865232917, 'dec'),
#  (0.013799054251363737, 'koi_prad'),
#  (0.013482417732569555, 'koi_time0bk'),
#  (0.012472738815852535, 'koi_steff_err1'),
#  (0.01216484974911961, 'koi_srad_err1'),
#  (0.010918051921612902, 'koi_duration'),
#  (0.010682474551519407, 'koi_steff_err2'),
#  (0.010030260217330758, 'koi_steff'),
#  (0.009726526528619491, 'koi_period'),
#  (0.008931434472302572, 'koi_slogg_err2'),
#  (0.008920089347426791, 'koi_kepmag'),
#  (0.008858457824265465, 'ra'),
#  (0.008574798857482071, 'koi_time0bk_err2'),
#  (0.008569787985835046, 'koi_prad_err1'),
#  (0.008353588166937292, 'koi_depth_err2'),
#  (0.008290934344142424, 'koi_time0bk_err1'),
#  (0.00814701604510312, 'koi_insol_err1'),
#  (0.00807468276259155, 'koi_depth_err1'),
#  (0.006309548041929808, 'koi_depth'),
#  (0.006179978453397545, 'koi_duration_err2'),
#  (0.0059829301689431555, 'koi_impact_err1'),
#  (0.005771161924301731, 'koi_impact_err2'),
#  (0.005566894802134939, 'koi_srad_err2'),
#  (0.005494272233356173, 'koi_duration_err1'),
#  (0.004757072206408919, 'koi_prad_err2'),
#  (0.0046710868349695124, 'koi_tce_plnt_num'),
#  (0.003958095685106485, 'koi_period_err1'),
#  (0.0037257987910912244, 'koi_teq'),
#  (0.0034274707634448986, 'koi_slogg'),
#  (0.003156931265442894, 'koi_insol'),
#  (0.003126160756427814, 'koi_slogg_err1'),
#  (0.002823537133551577, 'koi_insol_err2'),
#  (0.002770923675398147, 'koi_period_err2'),
#  (0.0015171380830816981, 'koi_srad')]
